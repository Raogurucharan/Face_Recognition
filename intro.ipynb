# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil=Image.open("THOR.jpg")

# %%
arr= np.array(pil)

# %%
arr.shape
# Out:
# (246, 220, 3)

# %%
cut=arr[:5, :5]

# %%
plt.imshow(cut)

# %%
red=arr[:,:, 0]

# %%
plt.imshow(red) """ """

# %%
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x246 at 0x26129332C88>

# %%
work=arr.copy()

# %%
work[:,:,[1,2]]=0

# %%
plt.imshow(work)
